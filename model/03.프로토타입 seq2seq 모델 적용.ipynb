# %%
from tensorflow import keras
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("./prototype_data.csv")

# %%
df.head()
# Out:
#                     일시  PM-10  ('풍속', 98)  ('풍속', 99)  ('풍속', 108)  \
# 0  2023-01-03 03:00:00   27.0   -1.001528   -1.276354    -0.794339
# 1  2023-01-03 06:00:00   29.0   -1.001528   -1.178118    -0.692980
# 2  2023-01-03 09:00:00   30.0   -0.902350   -1.276354    -0.895697
# 3  2023-01-03 12:00:00   41.0   -0.604817   -0.981647    -0.084830
# 4  2023-01-03 15:00:00   31.0    0.585315   -0.294000     0.827396
#
#    ('풍속', 112)  ('풍속', 119)  ('풍속', 133)  ('풍속', 201)  ('강수량', 98)  ...  \
# 0     0.077853    -0.865018    -0.777845    -1.041770    -0.194231  ...
# 1    -0.654746    -1.128880    -0.777845    -1.209365    -0.194231  ...
# 2    -1.533866    -1.304788    -0.863775    -0.957973    -0.194231  ...
# 3    -0.508227    -0.513201    -0.262265    -0.957973    -0.194231  ...
# 4     0.297633     0.982019     1.198545     0.466585    -0.194231  ...
#
#    month_11  month_12  hour_00  hour_03  hour_06  hour_09  hour_12  hour_15  \
# 0     False     False    False     True    False    False    False    False
# 1     False     False    False    False     True    False    False    False
# 2     False     False    False    False    False     True    False    False
# 3     False     False    False    False    False    False     True    False
# 4     False     False    False    False    False    False    False     True
#
#    hour_18  hour_21
# 0    False    False
# 1    False    False
# 2    False    False
# 3    False    False
# 4    False    False
#
# [5 rows x 613 columns]

# %%
df2 = df.set_index("일시")

# %%
df.shape
# Out:
# (2143, 613)

# %%
x = df2.drop("PM-10", axis = 1)

# %%
y = df2["PM-10"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= 0.3, random_state= 42)

# %%
# 훈련 세트와 검증 세트로 나누기
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size= 0.3, random_state= 42)

# %%
x_train.shape
# Out:
# (1050, 611)

# %% [markdown]
# ## Seq2seq

# %%
# 시퀀스 데이터 생성 함수 (Seq2Seq을 위해 input sequences와 output sequences를 분리)
def create_seq2seq_data(X, y, input_steps=16, output_steps=10): # X: 입력 특징(feature) 데이터프레임. y: 예측 대상 변수 시리즈. 
                                                                # input_steps: 인코더 입력 시퀀스의 길이. output_steps: 디코더 출력 시퀀스의 길이.
    Xs, ys = [], [] # Xs: 인코더 입력 시퀀스 배열. 각 시퀀스는 input_steps 길이의 데이터. ys: 디코더 출력 시퀀스 배열. 각 시퀀스는 output_steps 길이의 데이터.
    for i in range(len(X) - input_steps - output_steps): # X와 y에서 인코더와 디코더에 맞는 시퀀스를 생성
        Xs.append(X.iloc[i:(i + input_steps)].values) # 인코더 입력 시퀀스 생성
        ys.append(y.iloc[(i + input_steps):(i + input_steps + output_steps)].values) # 디코더 출력 시퀀스를 생성
    return np.array(Xs).astype(np.float32), np.array(ys).astype(np.float32)

input_steps = 16
output_steps = 10

# 함수를 사용하여 전체 데이터를 시퀀스 데이터로 변환
X_seq2seq, y_seq2seq = create_seq2seq_data(x, y, input_steps, output_steps) # 인코더 입력 시퀀스 배열. 디코더 출력 시퀀스 배열.

x_train, x_test, y_train, y_test = train_test_split(X_seq2seq, y_seq2seq, test_size=0.2, random_state=42)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense

# Encoder
encoder_inputs = Input(shape=(input_steps, x_train.shape[2])) # (input_steps, x_train.shape[2])는 각각 시퀀스 길이와 특징(feature) 수를 나타냄
encoder_lstm = LSTM(128, return_state=True) # return_state=True를 사용하여 LSTM의 최종 숨겨진 상태(state_h)와 셀 상태(state_c)를 반환
encoder_outputs, state_h, state_c = encoder_lstm(encoder_inputs)
encoder_states = [state_h, state_c] # 인코더의 상태를 디코더의 초기 상태로 사용하기 위해 리스트에 저장

# Decoder
decoder_inputs = Input(shape=(output_steps, x_train.shape[2])) # (output_steps, x_train.shape[2])는 각각 시퀀스 길이와 특징 수를 나타냄
decoder_lstm = LSTM(128, return_sequences=True, return_state=True) # return_state=True를 사용하여 전체 출력 시퀀스를 반환
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = Dense(1, activation='linear')
decoder_outputs = decoder_dense(decoder_outputs) # 디코더의 출력을 1차원 값으로 변환하는 Dense 레이어를 정의

# Define the model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs) # 인코더와 디코더를 연결하여 전체 Seq2Seq 모델을 정의

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')
checkpoint_cb = keras.callbacks.ModelCheckpoint("./seq2seq-model.keras", save_best_only = True)
early_stopping_cb = keras.callbacks.EarlyStopping(patience = 8, restore_best_weights = True)
# Model summary
model.summary()

# 디코더 입력 데이터 준비 - 디코더 입력 데이터를 모두 0으로 초기화
# 각 배열의 형태는 (샘플 수, 출력 스텝 수, 특징 수)로 설정
decoder_input_train = np.zeros((y_train.shape[0], output_steps, x_train.shape[2]))
decoder_input_val = np.zeros((y_val.shape[0], output_steps, x_train.shape[2]))
decoder_input_test = np.zeros((y_test.shape[0], output_steps, x_train.shape[2]))

# Training the model
history = model.fit([x_train, decoder_input_train], y_train, epochs=200, validation_data=([x_val, decoder_input_val], y_val))

# Evaluate the model
model.evaluate([x_test, decoder_input_test], y_test)

# Predict
predictions = model.predict([x_test, decoder_input_test])
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 16, 611)           │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ input_layer_1 (InputLayer)    │ (None, 10, 611)           │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm (LSTM)                   │ [(None, 128), (None,      │         378,880 │ input_layer[0][0]          │
# │                               │ 128), (None, 128)]        │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_1 (LSTM)                 │ [(None, 10, 128), (None,  │         378,880 │ input_layer_1[0][0],       │
# │                               │ 128), (None, 128)]        │                 │ lstm[0][1], lstm[0][2]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 10, 1)             │             129 │ lstm_1[0][0]               │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 757,889 (2.89 MB)
#  Trainable params: 757,889 (2.89 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 1687.9091 - val_loss: 1359.6083
# Epoch 2/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1031.0857 - val_loss: 1156.2747
# Epoch 3/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 810.3907 - val_loss: 1048.1602
# Epoch 4/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 718.1040 - val_loss: 986.3115
# Epoch 5/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 649.9003 - val_loss: 957.8717
# Epoch 6/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 680.8370 - val_loss: 935.6671
# Epoch 7/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 627.1324 - val_loss: 898.9193
# Epoch 8/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 594.3788 - val_loss: 843.8958
# Epoch 9/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 597.0394 - val_loss: 772.3323
# Epoch 10/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 555.1655 - val_loss: 714.5837
# Epoch 11/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 475.2685 - val_loss: 676.0203
# Epoch 12/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 441.8641 - val_loss: 637.9744
# Epoch 13/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 436.7462 - val_loss: 609.3291
# Epoch 14/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 387.6591 - val_loss: 580.3177
# Epoch 15/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 373.7846 - val_loss: 554.1342
# Epoch 16/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 381.9469 - val_loss: 529.1187
# Epoch 17/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 369.4404 - val_loss: 507.1002
# Epoch 18/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 324.1241 - val_loss: 485.8232
# Epoch 19/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 311.8096 - val_loss: 468.3033
# Epoch 20/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 320.4670 - val_loss: 454.0401
# Epoch 21/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 266.8831 - val_loss: 436.0013
# Epoch 22/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 262.8649 - val_loss: 441.2823
# Epoch 23/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 248.0174 - val_loss: 405.3253
# Epoch 24/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 227.8698 - val_loss: 385.7858
# Epoch 25/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 263.7173 - val_loss: 371.0243
# Epoch 26/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 194.4864 - val_loss: 354.0701
# Epoch 27/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 199.5346 - val_loss: 343.3438
# Epoch 28/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 182.5715 - val_loss: 324.3241
# Epoch 29/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 184.0264 - val_loss: 313.3001
# Epoch 30/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 161.3169 - val_loss: 297.8308
# Epoch 31/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 141.8606 - val_loss: 289.8250
# Epoch 32/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 142.7767 - val_loss: 281.4083
# Epoch 33/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 151.1525 - val_loss: 268.5814
# Epoch 34/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 143.2479 - val_loss: 257.4769
# Epoch 35/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 126.6320 - val_loss: 248.7629
# Epoch 36/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 113.7537 - val_loss: 241.0089
# Epoch 37/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 128.0613 - val_loss: 232.1839
# Epoch 38/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 100.6587 - val_loss: 224.9196
# Epoch 39/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 126.8805 - val_loss: 221.3088
# Epoch 40/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 93.1316 - val_loss: 211.3914
# Epoch 41/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 89.2019 - val_loss: 211.0009
# Epoch 42/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 95.8252 - val_loss: 202.6224
# Epoch 43/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 92.1748 - val_loss: 203.5951
# Epoch 44/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 97.1690 - val_loss: 195.8200
# Epoch 45/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 90.6998 - val_loss: 188.3254
# Epoch 46/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 90.2425 - val_loss: 185.9997
# Epoch 47/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 79.0250 - val_loss: 182.2432
# Epoch 48/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 78.6867 - val_loss: 181.1955
# Epoch 49/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 69.6954 - val_loss: 177.3741
# Epoch 50/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 74.2611 - val_loss: 172.8608
# Epoch 51/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 71.5889 - val_loss: 172.4299
# Epoch 52/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 65.4782 - val_loss: 168.7197
# Epoch 53/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 64.4185 - val_loss: 164.6050
# Epoch 54/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 58.4523 - val_loss: 159.9009
# Epoch 55/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 62.5332 - val_loss: 158.0890
# Epoch 56/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 58.5968 - val_loss: 156.1979
# Epoch 57/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 69.9653 - val_loss: 154.4657
# Epoch 58/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 69.1260 - val_loss: 150.9058
# Epoch 59/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 56.9454 - val_loss: 153.5185
# Epoch 60/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 65.3352 - val_loss: 149.5651
# Epoch 61/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 52.5462 - val_loss: 146.5005
# Epoch 62/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 60.0031 - val_loss: 144.5550
# Epoch 63/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 44.8841 - val_loss: 145.8492
# Epoch 64/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 54.7285 - val_loss: 141.4518
# Epoch 65/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 47.0637 - val_loss: 144.3195
# Epoch 66/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 51.5025 - val_loss: 140.6510
# Epoch 67/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 57.8691 - val_loss: 139.3581
# Epoch 68/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 51.2912 - val_loss: 139.9866
# Epoch 69/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 52.4664 - val_loss: 137.6784
# Epoch 70/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 48.4974 - val_loss: 133.9302
# Epoch 71/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 44.8496 - val_loss: 133.2681
# Epoch 72/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 44.6812 - val_loss: 133.8150
# Epoch 73/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 43.6131 - val_loss: 128.9330
# Epoch 74/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 46.2368 - val_loss: 126.9900
# Epoch 75/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 37.3822 - val_loss: 128.2493
# Epoch 76/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 40.7785 - val_loss: 126.7844
# Epoch 77/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 41.1575 - val_loss: 130.6873
# Epoch 78/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 41.7753 - val_loss: 133.6806
# Epoch 79/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 39.7233 - val_loss: 131.9607
# Epoch 80/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 39.3845 - val_loss: 126.8312
# Epoch 81/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 43.5138 - val_loss: 123.9591
# Epoch 82/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 35.6519 - val_loss: 127.4399
# Epoch 83/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 37.3319 - val_loss: 122.2510
# Epoch 84/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 39.5565 - val_loss: 124.6770
# Epoch 85/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 40.7035 - val_loss: 123.8962
# Epoch 86/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 38.4756 - val_loss: 120.3668
# Epoch 87/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 41.4313 - val_loss: 120.5464
# Epoch 88/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 36.3760 - val_loss: 125.9818
# Epoch 89/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 27.2997 - val_loss: 119.3636
# Epoch 90/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 29.3291 - val_loss: 122.6292
# Epoch 91/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 27.3366 - val_loss: 114.5677
# Epoch 92/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.3449 - val_loss: 116.4582
# Epoch 93/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 30.2777 - val_loss: 119.4696
# Epoch 94/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 31.1440 - val_loss: 117.0025
# Epoch 95/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 26.2626 - val_loss: 111.7494
# Epoch 96/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 27.0212 - val_loss: 120.9994
# Epoch 97/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.6114 - val_loss: 110.7860
# Epoch 98/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.6958 - val_loss: 115.0427
# Epoch 99/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 19.1305 - val_loss: 108.8952
# Epoch 100/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.5725 - val_loss: 109.6576
# Epoch 101/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.7838 - val_loss: 110.3526
# Epoch 102/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.4904 - val_loss: 120.7740
# Epoch 103/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 30.6493 - val_loss: 105.4651
# Epoch 104/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.1490 - val_loss: 121.5675
# Epoch 105/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 28.0107 - val_loss: 111.8321
# Epoch 106/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 26.3410 - val_loss: 114.5324
# Epoch 107/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.9758 - val_loss: 107.6178
# Epoch 108/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.8250 - val_loss: 110.7041
# Epoch 109/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.0534 - val_loss: 112.4014
# Epoch 110/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.2693 - val_loss: 107.5809
# Epoch 111/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.8016 - val_loss: 110.2065
# Epoch 112/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.4946 - val_loss: 106.9210
# Epoch 113/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 19.6256 - val_loss: 107.3990
# Epoch 114/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.2659 - val_loss: 105.3534
# Epoch 115/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 18.0243 - val_loss: 105.2974
# Epoch 116/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.3300 - val_loss: 112.4683
# Epoch 117/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 36.3942 - val_loss: 118.5630
# Epoch 118/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.1346 - val_loss: 117.3923
# Epoch 119/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.6895 - val_loss: 107.9093
# Epoch 120/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 18.9489 - val_loss: 102.3117
# Epoch 121/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 13.2636 - val_loss: 104.7948
# Epoch 122/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11.5485 - val_loss: 104.3157
# Epoch 123/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 15.8197 - val_loss: 103.8164
# Epoch 124/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 12.6715 - val_loss: 100.9367
# Epoch 125/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 13.2455 - val_loss: 103.4824
# Epoch 126/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.6895 - val_loss: 103.5725
# Epoch 127/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.4481 - val_loss: 106.0252
# Epoch 128/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.7511 - val_loss: 101.3358
# Epoch 129/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11.2827 - val_loss: 104.5196
# Epoch 130/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.7811 - val_loss: 108.9492
# Epoch 131/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11.7031 - val_loss: 105.4020
# Epoch 132/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.1215 - val_loss: 107.7028
# Epoch 133/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.8242 - val_loss: 104.7526
# Epoch 134/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.0851 - val_loss: 106.8531
# Epoch 135/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11.2987 - val_loss: 105.3760
# Epoch 136/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 12.2462 - val_loss: 103.7165
# Epoch 137/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.1952 - val_loss: 112.1543
# Epoch 138/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.9839 - val_loss: 104.7540
# Epoch 139/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.1892 - val_loss: 116.7631
# Epoch 140/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 18.7670 - val_loss: 102.2728
# Epoch 141/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.4036 - val_loss: 102.3438
# Epoch 142/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.1610 - val_loss: 104.4556
# Epoch 143/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.7323 - val_loss: 103.8852
# Epoch 144/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.7981 - val_loss: 103.8498
# Epoch 145/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.5923 - val_loss: 103.7851
# Epoch 146/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.0768 - val_loss: 106.1483
# Epoch 147/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11.7483 - val_loss: 109.4407
# Epoch 148/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11.2011 - val_loss: 111.8301
# Epoch 149/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.1909 - val_loss: 107.0130
# Epoch 150/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.2707 - val_loss: 108.3686
# Epoch 151/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.9290 - val_loss: 106.2926
# Epoch 152/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.5821 - val_loss: 106.6989
# Epoch 153/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.1454 - val_loss: 105.1213
# Epoch 154/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.2741 - val_loss: 108.1460
# Epoch 155/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.9002 - val_loss: 110.0447
# Epoch 156/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7745 - val_loss: 106.6246
# Epoch 157/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.1205 - val_loss: 106.2167
# Epoch 158/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.4463 - val_loss: 109.9504
# Epoch 159/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.2937 - val_loss: 105.2085
# Epoch 160/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.6436 - val_loss: 106.8246
# Epoch 161/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.0181 - val_loss: 106.6761
# Epoch 162/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.0102 - val_loss: 106.8150
# Epoch 163/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.6390 - val_loss: 106.5082
# Epoch 164/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.1197 - val_loss: 110.3646
# Epoch 165/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.4787 - val_loss: 104.3116
# Epoch 166/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.6128 - val_loss: 105.9887
# Epoch 167/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.2418 - val_loss: 108.9846
# Epoch 168/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.3391 - val_loss: 107.7975
# Epoch 169/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.7937 - val_loss: 107.9007
# Epoch 170/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5409 - val_loss: 109.4827
# Epoch 171/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7881 - val_loss: 110.2054
# Epoch 172/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.8885 - val_loss: 112.0448
# Epoch 173/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.0558 - val_loss: 114.5036
# Epoch 174/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.5639 - val_loss: 112.7638
# Epoch 175/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.5691 - val_loss: 123.2019
# Epoch 176/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11.6656 - val_loss: 114.3177
# Epoch 177/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.4163 - val_loss: 110.8689
# Epoch 178/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.5239 - val_loss: 109.4508
# Epoch 179/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.2441 - val_loss: 110.4617
# Epoch 180/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.2525 - val_loss: 112.6450
# Epoch 181/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.5232 - val_loss: 109.2367
# Epoch 182/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.4275 - val_loss: 113.5561
# Epoch 183/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5273 - val_loss: 112.3085
# Epoch 184/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.1146 - val_loss: 108.8006
# Epoch 185/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7736 - val_loss: 112.1528
# Epoch 186/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.3791 - val_loss: 110.3989
# Epoch 187/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0863 - val_loss: 109.1429
# Epoch 188/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6238 - val_loss: 109.3730
# Epoch 189/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5014 - val_loss: 110.8367
# Epoch 190/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3995 - val_loss: 109.8719
# Epoch 191/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5065 - val_loss: 110.2060
# Epoch 192/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2242 - val_loss: 110.3370
# Epoch 193/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2382 - val_loss: 111.5098
# Epoch 194/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1927 - val_loss: 109.7953
# Epoch 195/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9435 - val_loss: 114.8003
# Epoch 196/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.3825 - val_loss: 113.6111
# Epoch 197/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.2713 - val_loss: 115.3710
# Epoch 198/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.1372 - val_loss: 114.2373
# Epoch 199/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8400 - val_loss: 115.4345
# Epoch 200/200
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.5049 - val_loss: 112.2601
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 108.9851
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
predictions[:10]
# Out:
# array([[[ 50.833645 ],
#         [ 46.22729  ],
#         [ 43.92582  ],
#         [ 35.685085 ],
#         [ 33.75869  ],
#         [ 38.49796  ],
#         [ 39.813206 ],
#         [ 36.77084  ],
#         [ 42.234436 ],
#         [ 48.631824 ]],
#
#        [[ 16.877317 ],
#         [ 21.697895 ],
#         [ 20.724983 ],
#         [ 18.71252  ],
#         [ 18.015448 ],
#         [ 27.545742 ],
#         [ 27.014322 ],
#         [ 24.215242 ],
#         [ 29.211443 ],
#         [ 27.958649 ]],
#
#        [[ 78.107666 ],
#         [ 79.76891  ],
#         [ 60.578762 ],
#         [ 53.790646 ],
#         [ 64.44048  ],
#         [ 70.868225 ],
#         [ 82.4113   ],
#         [ 83.68003  ],
#         [ 86.47473  ],
#         [101.10961  ]],
#
#        [[ 80.924095 ],
#         [ 86.70459  ],
#         [ 85.28219  ],
#         [ 90.86628  ],
#         [ 67.11007  ],
#         [ 33.04622  ],
#         [ 30.339457 ],
#         [ 25.7501   ],
#         [ 23.88134  ],
#         [ 25.940361 ]],
#
#        [[ 27.138533 ],
#         [ 30.169891 ],
#         [ 31.846199 ],
#         [ 32.6341   ],
#         [ 27.601093 ],
#         [ 37.87325  ],
#         [ 54.46109  ],
#         [ 63.45642  ],
#         [ 35.3179   ],
#         [ 27.960262 ]],
#
#        [[ 27.438374 ],
#         [ 33.921127 ],
#         [ 62.896122 ],
#         [ 51.535484 ],
#         [ 33.72491  ],
#         [ 36.78591  ],
#         [ 41.958164 ],
#         [ 56.685078 ],
#         [ 83.52967  ],
#         [ 91.29667  ]],
#
#        [[ 17.88669  ],
#         [ 18.02484  ],
#         [ 27.426937 ],
#         [ 46.532307 ],
#         [ 28.420454 ],
#         [ 26.996704 ],
#         [ 30.00132  ],
#         [ 36.571697 ],
#         [ 58.94865  ],
#         [ 59.950603 ]],
#
#        [[ 15.417289 ],
#         [ 20.519016 ],
#         [ 22.69897  ],
#         [ 27.297089 ],
#         [ 27.520477 ],
#         [ 23.166695 ],
#         [ 24.012299 ],
#         [ 23.265255 ],
#         [ 15.5836525],
#         [ 19.296806 ]],
#
#        [[ 34.688465 ],
#         [ 31.804825 ],
#         [ 32.381233 ],
#         [ 33.546238 ],
#         [ 48.72633  ],
#         [ 49.845234 ],
#         [ 44.20461  ],
#         [ 43.329388 ],
#         [ 56.057808 ],
#         [ 60.459126 ]],
#
#        [[ 22.014385 ],
#         [ 16.227573 ],
#         [ 16.576784 ],
#         [ 21.93282  ],
#         [ 20.823923 ],
#         [ 22.340982 ],
#         [ 25.5762   ],
#         [ 29.385786 ],
#         [ 25.929733 ],
#         [ 30.533464 ]]], dtype=float32)

# %%
y_test[:10]
# Out:
# array([[ 48.,  46.,  43.,  40.,  38.,  38.,  39.,  33.,  41.,  40.],
#        [ 24.,  15.,  14.,  12.,  24.,  29.,  24.,  31.,  32.,  43.],
#        [ 70.,  69.,  77.,  60.,  54.,  67.,  80.,  91.,  76.,  85.],
#        [101.,  93.,  81.,  98.,  67.,  35.,  32.,  25.,  21.,  12.],
#        [ 29.,  25.,  34.,  27.,  34.,  42.,  54.,  62.,  31.,  25.],
#        [ 24.,  46.,  53.,  31.,  27.,  33.,  51.,  74.,  97.,  85.],
#        [ 12.,  13.,  39.,  39.,  30.,  28.,  25.,  42.,  61.,  63.],
#        [ 20.,  26.,  28.,  27.,  19.,  21.,  23.,  21.,  25.,  20.],
#        [ 37.,  38.,  35.,  42.,  49.,  40.,  42.,  49.,  55.,  40.],
#        [ 26.,  22.,  15.,  21.,  26.,  21.,  22.,  31.,  26.,  32.]],
#       dtype=float32)
